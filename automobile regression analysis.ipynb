# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Surendra/Desktop/data science/projects/govt data/auto_data')

# %%
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df.columns = ['symboling','normalized-losses','make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels'
                ,'engine-location','wheel-base','length','width','height','curb-weight','engine-type',
                'num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower'
                ,'peak-rpm','city-mpg','highway-mpg','price']

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data = df.replace('?' , 0)

# %%
data['horsepower'] = data["horsepower"].astype(float)

# %%
data["make"]= data["make"].astype(str)

# %%
data['engine-size'] = data['engine-size'].astype(float)

# %%
data['city-mpg'] = data['city-mpg'].astype(float)

# %%
data['highway-mpg'] = data['highway-mpg'].astype(float)

# %%
x = data[['engine-size','symboling']]
x.shape
# Out:
# (204, 2)

# %%
x
# Out:
# 0      130.0
# 1      152.0
# 2      109.0
# 3      136.0
# 4      136.0
#        ...
# 199    141.0
# 200    141.0
# 201    173.0
# 202    145.0
# 203    141.0
# Name: engine-size, Length: 204, dtype: float64

# %%
y = data['horsepower']

# %%
y.shape
# Out:
# (204,)

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,'ro')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =0)

# %%
x_train.shape
# Out:
# (163, 2)

# %%
y_train.shape
# Out:
# (163, 2)

# %%
x_test.shape
# Out:
# (41, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# [ 1.73812066e+00 -4.44089210e-16]

# %%
print(lr.coef_)
# Out:
# [[7.76678104e-01 4.39598309e+00]
#  [7.99437524e-19 1.00000000e+00]]

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([[ 7.60351331e+01,  1.00000000e+00],
#        [ 1.02954781e+02,  2.00000000e+00],
#        [ 7.75884893e+01,  1.00000000e+00],
#        [ 8.71727121e+01, -3.56151082e-16],
#        [ 1.19793192e+02, -3.22574706e-16],
#        [ 8.14718799e+01,  1.00000000e+00],
#        [ 1.11762326e+02,  1.00000000e+00],
#        [ 1.32204464e+02,  3.00000000e+00],
#        [ 1.29113330e+02, -3.12981456e-16],
#        [ 7.31925062e+01, -3.70540958e-16],
#        [ 9.64928494e+01, -3.46557832e-16],
#        [ 9.51880002e+01,  2.00000000e+00],
#        [ 1.23925090e+02,  2.00000000e+00],
#        [ 7.78525749e+01, -3.65744333e-16],
#        [ 7.78525749e+01, -3.65744333e-16],
#        [ 1.07878935e+02,  1.00000000e+00],
#        [ 1.04259630e+02, -3.38563457e-16],
#        [ 1.08904121e+02,  3.00000000e+00],
#        [ 8.19844724e+01,  2.00000000e+00],
#        [ 1.39474231e+02, -1.00000000e+00],
#        [ 7.16391500e+01, -3.72139833e-16],
#        [ 8.56193559e+01, -3.57749957e-16],
# ...

# %%
y_test
# Out:
#      horsepower  symboling
# 18         70.0          1
# 45         90.0          2
# 33         76.0          1
# 37         86.0          0
# 109        95.0          0
# 90         69.0          1
# 5         110.0          1
# 124       143.0          3
# 12        121.0          0
# 153        62.0          0
# 61         84.0          0
# 187       100.0          2
# 166       116.0          2
# 160        70.0          0
# 155        70.0          0
# 7         140.0          1
# 129         0.0          0
# 131       110.0          3
# 75         68.0          2
# 66        123.0         -1
# 44         70.0          0
# 146        94.0          0
# 63         84.0          0
# 135       160.0          3
# 86        116.0          1
# 141        82.0          0
# 188        90.0          3
# 182        85.0          2
# 161        70.0          0
# 96         69.0          1
# 203       114.0         -1
# 60         84.0          1
# 16        182.0          0
# ...

# %%
plt.plot(x_test,y_test,'rx')
plt.plot(x_test,y_pred, c = 'blck')
